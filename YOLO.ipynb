# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n.yaml")

# %%
model.is_hub_model("yolo11n.yaml")
# Out:
# False

# %%
model._new("yolo11n.yaml")

# %%
from ultralytics.nn.tasks import attempt_load_one_weight, guess_model_task, yaml_model_load

# %%
yaml_model_load("yolo11n.yaml")
# Out:
# {'nc': 80,
#  'scales': {'n': [0.5, 0.25, 1024],
#   's': [0.5, 0.5, 1024],
#   'm': [0.5, 1.0, 512],
#   'l': [1.0, 1.0, 512],
#   'x': [1.0, 1.5, 512]},
#  'backbone': [[-1, 1, 'Conv', [64, 3, 2]],
#   [-1, 1, 'Conv', [128, 3, 2]],
#   [-1, 2, 'C3k2', [256, False, 0.25]],
#   [-1, 1, 'Conv', [256, 3, 2]],
#   [-1, 2, 'C3k2', [512, False, 0.25]],
#   [-1, 1, 'Conv', [512, 3, 2]],
#   [-1, 2, 'C3k2', [512, True]],
#   [-1, 1, 'Conv', [1024, 3, 2]],
#   [-1, 2, 'C3k2', [1024, True]],
#   [-1, 1, 'SPPF', [1024, 5]],
#   [-1, 2, 'C2PSA', [1024]]],
#  'head': [[-1, 1, 'nn.Upsample', ['None', 2, 'nearest']],
#   [[-1, 6], 1, 'Concat', [1]],
#   [-1, 2, 'C3k2', [512, False]],
#   [-1, 1, 'nn.Upsample', ['None', 2, 'nearest']],
#   [[-1, 4], 1, 'Concat', [1]],
#   [-1, 2, 'C3k2', [256, False]],
#   [-1, 1, 'Conv', [256, 3, 2]],
#   [[-1, 13], 1, 'Concat', [1]],
#   [-1, 2, 'C3k2', [512, False]],
#   [-1, 1, 'Conv', [512, 3, 2]],
#   [[-1, 10], 1, 'Concat', [1]],
# ...

# %%
model.info(True)
# Out:
# layer                                    name                type  gradient  parameters               shape        mu     sigma
#     0                     model.0.conv.weight              Conv2d      True         432       [16, 3, 3, 3]    0.0114     0.108        float32
#     1                       model.0.bn.weight         BatchNorm2d      True          16                [16]         1         0        float32
#     1                         model.0.bn.bias         BatchNorm2d      True          16                [16]         0         0        float32
#     2                             model.0.act                SiLU     False           0                  []         -         -              -
#     3                     model.1.conv.weight              Conv2d      True        4608      [32, 16, 3, 3]  0.000722     0.048        float32
#     4                       model.1.bn.weight         BatchNorm2d      True          32                [32]         1         0        float32
# ...

# %%
results = model.train(data="coco8.yaml", device="cpu", epochs=1, batch=1, imgsz=320, workers= 0)
# Out:
# New https://pypi.org/project/ultralytics/8.3.209 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.184  Python-3.12.4 torch-2.5.1+cpu CPU (Intel Core(TM) i7-4700HQ 2.40GHz)
# ...
