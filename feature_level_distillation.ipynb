# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
from ultralytics import YOLO
model = YOLO("yolo11n.pt")
results = model.train(
    data="coco8.yaml", 
    epochs=10, 
    imgsz=640,
    teacher_model= "E:/00.MOTHER_BOXES/code/modification/ultralytics/yolo11_n3x.yaml", #teacher model path for distillation
    mask_type = "pyramid", # original or pyramid
    # distillation of classification head
    cls_dist = True, # distills cls with bce if we set dist_kl to False
    cls_dist_kl = False, # distills cls with kl divergence if true else bce distillation
    cls_fg_mask = True , # Set to True to apply spatial foreground mask, False to disable
    cls_dist_t= 1.,# cls temperature parameter
    cls_alpha= 1., # cls distillation loss multiplier
    # distillation of bounding box head
    dfl_dist = True, # distilling directly dfl head for bb
    dfl_fg_mask = True,
    dfl_t= 1.,
    dfl_alpha= 1.,
    # our proposed m2d2 multimodal distillation for dfl heads internally poses the mask so we should first set the mask
    M2D2 = True,
    m2d2_t= 1.,
    m2d2_alpha= 1.,
    # distilling bounding box head using regression first converts dfl to continouos values then distills it
    l2_dist = True,
    l2_fg_mask = False,  # Set to False to disable spatial masking
    l2_alpha= 1., # regression head distillation loss mutiplier
    # distilling neck features in different forms from raw features to attention based and masked by TAL
    feat_distill = True ,# to enable neck features return and avoid code breaking
    feat = True, # calculate whole feature maps and supports masking
    feat_att = True, # calculates attention maps and supports masking
    feat_mask = True, # True if we want to apply mask to feat and feat_att and other methods of distillation listed bellow
    loss_ty = "cosine", #"l2 or cosine when feat or feat_att is set to true"
    feat_oth = True, #"following methods could be applied if this one set to true"
    # choose only one of the followings
    use_cwd= True, # Channel-Wise Distillation (CWD)
    use_crd= False, # Correlation / Relational Distillation (CRD-style)
    use_mmd= False, # Feature Distribution Matching (MMD)
    use_spatial_att= False, # Spatial Softmax Attention Distillation
    use_channel_att= False, # Channel Attention Distillation (SE-style)
    # hyper parameters for all feature level distillation
    level_weights= [1., 1., 1.], # channel weights for all feature distillation and cls distillation
    feature_lambda= 1., # feature loss weight multiplier
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.12 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.184  Python-3.12.4 torch-2.5.1+cpu CPU (Intel Core(TM) i7-4700HQ 2.40GHz)
# engine\trainer: M2D2=True, agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_alpha=1.0, cls_dist=True, cls_dist_kl=False, cls_dist_t=1.0, cls_fg_mask=True, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=coco8.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dfl_alpha=1.0, dfl_dist=True, dfl_fg_mask=True, dfl_t=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, feat=True, feat_att=True, feat_distill=True, feat_mask=True, feat_oth=True, feature_lambda=1.0, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, l2_alpha=1.0, l2_dist=True, l2_fg_mask=False, level_weights=[1.0, 1.0, 1.0], line_width=None, loss_ty=cosine, lr0=0.01, lrf=0.01, m2d2_alpha=1.0, m2d2_t=1.0, mask_ratio=4, mask_type=pyramid, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs\detect\train4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, teacher_model=E:/00.MOTHER_BOXES/code/modification/ultralytics/yolo11_n3x.yaml, time=None, tracker=botsort.yaml, translate=0.1, use_channel_att=False, use_crd=False, use_cwd=True, use_mmd=False, use_spatial_att=False, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    464912  ultralytics.nn.modules.head.Detect           [80, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,624,080 parameters, 2,624,064 gradients, 6.6 GFLOPs
#
# Transferred 499/499 items from pretrained weights
# WARNING no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  1     58320  ultralytics.nn.modules.block.C3k2            [96, 192, 1, False, 0.25]
#   3                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#   4                  -1  1    231840  ultralytics.nn.modules.block.C3k2            [192, 384, 1, False, 0.25]
#   5                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   6                  -1  1    777216  ultralytics.nn.modules.block.C3k2            [384, 384, 1, True]
#   7                  -1  1   2655744  ultralytics.nn.modules.conv.Conv             [384, 768, 3, 2]
#   8                  -1  1   3102720  ultralytics.nn.modules.block.C3k2            [768, 768, 1, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5]
#  10                  -1  1   2223744  ultralytics.nn.modules.block.C2PSA           [768, 768, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    997440  ultralytics.nn.modules.block.C3k2            [1152, 384, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    286752  ultralytics.nn.modules.block.C3k2            [768, 192, 1, False]
#  17                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    776256  ultralytics.nn.modules.block.C3k2            [576, 384, 1, False]
#  20                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   3397632  ultralytics.nn.modules.block.C3k2            [1152, 768, 1, True]
#  23        [16, 19, 22]  1   1336384  ultralytics.nn.modules.head.Detect           [80, [192, 384, 768]]
# YOLO11_n3x summary: 181 layers, 20,684,032 parameters, 20,684,016 gradients, 46.3 GFLOPs
#
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.0 ms, read: 26.949.0 MB/s, size: 50.0 KB)
# train: Scanning E:\00.MOTHER_BOXES\code\modification\datasets\coco8\labels\train.cache... 4 images, 0 backgrounds, 0 co
# val: Fast image access  (ping: 0.10.0 ms, read: 15.926.0 MB/s, size: 54.0 KB)
# val: Scanning E:\00.MOTHER_BOXES\code\modification\datasets\coco8\labels\val.cache... 4 images, 0 backgrounds, 0 corrup
# Plotting labels to runs\detect\train4\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# Adaptor LR: 0.000119
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\detect\train4
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10         0G      1.029      1.927      1.343         13        640: 100%|██████████| 1/1 [00:45<00:00, 45.96
# Epoch 1: cls_distill_loss=0.007188, dfl_distill_loss=2.931765, m2d2_distill_loss=2.971177, box_reg_distill_loss=0.080874, feat_l2_loss=0.996838, feat_att_loss=0.007373, feat_other_loss=0.160879
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:15<0
#                    all          4         17      0.595       0.85      0.849      0.632
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10         0G      1.263      2.464      1.612         13        640: 100%|██████████| 1/1 [00:09<00:00,  9.05
# Epoch 2: cls_distill_loss=0.007473, dfl_distill_loss=2.519434, m2d2_distill_loss=2.539093, box_reg_distill_loss=0.081752, feat_l2_loss=1.007190, feat_att_loss=0.013572, feat_other_loss=0.162094
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<0
#                    all          4         17      0.578       0.85      0.848      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10         0G      0.777      2.095      1.202         13        640: 100%|██████████| 1/1 [00:07<00:00,  7.26
# Epoch 3: cls_distill_loss=0.004808, dfl_distill_loss=2.581342, m2d2_distill_loss=2.613995, box_reg_distill_loss=0.081426, feat_l2_loss=0.996245, feat_att_loss=0.017603, feat_other_loss=0.151843
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<0
#                    all          4         17      0.591       0.85      0.849       0.65
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10         0G     0.9823      1.645       1.24         13        640: 100%|██████████| 1/1 [00:08<00:00,  8.06
# Epoch 4: cls_distill_loss=0.010046, dfl_distill_loss=3.060397, m2d2_distill_loss=3.043701, box_reg_distill_loss=0.080583, feat_l2_loss=1.007759, feat_att_loss=0.007845, feat_other_loss=0.171376
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<0
#                    all          4         17      0.614       0.85      0.849       0.65
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10         0G     0.7459      1.817        1.1         13        640: 100%|██████████| 1/1 [00:07<00:00,  7.10
# Epoch 5: cls_distill_loss=0.009752, dfl_distill_loss=3.628282, m2d2_distill_loss=3.668566, box_reg_distill_loss=0.080011, feat_l2_loss=1.006079, feat_att_loss=0.006776, feat_other_loss=0.155694
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<0
#                    all          4         17      0.623       0.85      0.878      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10         0G      1.229      2.655      1.528         13        640: 100%|██████████| 1/1 [00:06<00:00,  6.97
# Epoch 6: cls_distill_loss=0.005062, dfl_distill_loss=3.035592, m2d2_distill_loss=3.082168, box_reg_distill_loss=0.080269, feat_l2_loss=1.014340, feat_att_loss=0.014629, feat_other_loss=0.159794
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<0
#                    all          4         17      0.637       0.85      0.853      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10         0G      1.195      1.954      1.387         13        640: 100%|██████████| 1/1 [00:06<00:00,  6.91
# Epoch 7: cls_distill_loss=0.006558, dfl_distill_loss=3.877746, m2d2_distill_loss=3.876209, box_reg_distill_loss=0.078968, feat_l2_loss=1.005615, feat_att_loss=0.003295, feat_other_loss=0.165043
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<0
#                    all          4         17       0.65       0.85      0.853      0.634
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10         0G     0.9311      1.778      1.298         13        640: 100%|██████████| 1/1 [00:06<00:00,  6.67
# Epoch 8: cls_distill_loss=0.008432, dfl_distill_loss=2.665584, m2d2_distill_loss=2.691219, box_reg_distill_loss=0.081943, feat_l2_loss=1.002859, feat_att_loss=0.011250, feat_other_loss=0.162203
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17      0.651       0.85      0.855      0.635
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10         0G      1.082      1.765      1.315         13        640: 100%|██████████| 1/1 [00:06<00:00,  6.65
# Epoch 9: cls_distill_loss=0.014295, dfl_distill_loss=3.925294, m2d2_distill_loss=3.925356, box_reg_distill_loss=0.079307, feat_l2_loss=1.000690, feat_att_loss=0.004597, feat_other_loss=0.165218
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<0
#                    all          4         17      0.661       0.85      0.857      0.635
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10         0G      1.062      2.265      1.355         13        640: 100%|██████████| 1/1 [00:07<00:00,  7.48
# Epoch 10: cls_distill_loss=0.006192, dfl_distill_loss=3.127053, m2d2_distill_loss=3.120732, box_reg_distill_loss=0.079986, feat_l2_loss=1.022185, feat_att_loss=0.008411, feat_other_loss=0.159389
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<0
#                    all          4         17      0.668       0.85      0.855      0.636
# 10 epochs completed in 0.044 hours.
