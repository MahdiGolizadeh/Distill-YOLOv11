# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
from ultralytics import YOLO
model = YOLO("yolo11n.pt")
results = model.train(
    data="coco8.yaml", 
    epochs=10, 
    imgsz=640,
    teacher_model= "E:/00.MOTHER_BOXES/code/modification/yolo11_2x.yaml", #teacher model path for distillation
    mask_type = "pyramid", # original or pyramid
    # distillation of classification head
    cls_dist = True, # distills cls with bce if we set dist_kl to False
    cls_dist_kl = False, # distills cls with kl divergence if true else bce distillation
    cls_fg_mask = True , # Set to True to apply spatial foreground mask, False to disable
    cls_dist_t= 1.,# cls temperature parameter
    cls_alpha= 1., # cls distillation loss multiplier
    # distillation of bounding box head
    dfl_dist = True, # distilling directly dfl head for bb
    dfl_fg_mask = True,
    dfl_t= 1.,
    dfl_alpha= 1.,
    # our proposed m2d2 multimodal distillation for dfl heads internally poses the mask so we should first set the mask
    M2D2 = True,
    m2d2_t= 1.,
    m2d2_alpha= 1.,
    # distilling bounding box head using regression first converts dfl to continouos values then distills it
    l2_dist = True,
    l2_fg_mask = False,  # Set to False to disable spatial masking
    l2_alpha= 1., # regression head distillation loss mutiplier
    # distilling neck features in different forms from raw features to attention based and masked by TAL
    feat_distill = True ,# to enable neck features return and avoid code breaking
    feat = True, # calculate whole feature maps and supports masking
    feat_att = True, # calculates attention maps and supports masking
    feat_mask = True, # True if we want to apply mask to feat and feat_att and other methods of distillation listed bellow
    loss_ty = "cosine", #"l2 or cosine when feat or feat_att is set to true"
    feat_oth = True, #"following methods could be applied if this one set to true"
    # choose only one of the followings
    use_cwd= True, # Channel-Wise Distillation (CWD)
    use_crd= False, # Correlation / Relational Distillation (CRD-style)
    use_mmd= False, # Feature Distribution Matching (MMD)
    use_spatial_att= False, # Spatial Softmax Attention Distillation
    use_channel_att= False, # Channel Attention Distillation (SE-style)
    # hyper parameters for all feature level distillation
    level_weights= [1., 1., 1.], # channel weights for all feature distillation and cls distillation
    feature_lambda= 1., # feature loss weight multiplier
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.241 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.184  Python-3.12.4 torch-2.5.1+cpu CPU (Intel Core(TM) i7-4700HQ 2.40GHz)
# engine\trainer: M2D2=True, agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_alpha=1.0, cls_dist=True, cls_dist_kl=False, cls_dist_t=1.0, cls_fg_mask=True, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=coco8.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dfl_alpha=1.0, dfl_dist=True, dfl_fg_mask=True, dfl_t=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, feat=True, feat_att=True, feat_distill=True, feat_mask=True, feat_oth=True, feature_lambda=1.0, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, l2_alpha=1.0, l2_dist=True, l2_fg_mask=False, level_weights=[1.0, 1.0, 1.0], line_width=None, loss_ty=cosine, lr0=0.01, lrf=0.01, m2d2_alpha=1.0, m2d2_t=1.0, mask_ratio=4, mask_type=pyramid, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train127, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs\detect\train127, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, teacher_model=E:/00.MOTHER_BOXES/code/modification/yolo11_2x.yaml, time=None, tracker=botsort.yaml, translate=0.1, use_channel_att=False, use_crd=False, use_cwd=True, use_mmd=False, use_spatial_att=False, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    464912  ultralytics.nn.modules.head.Detect           [80, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,624,080 parameters, 2,624,064 gradients, 6.6 GFLOPs
#
# Transferred 499/499 items from pretrained weights
# WARNING no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    850368  ultralytics.nn.modules.head.Detect           [80, [128, 256, 512]]
# YOLO11_2x summary: 181 layers, 9,458,752 parameters, 9,458,736 gradients, 21.7 GFLOPs
#
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.0 ms, read: 216.973.1 MB/s, size: 50.0 KB)
# train: Scanning E:\00.MOTHER_BOXES\code\modification\datasets\coco8\labels\train.cache... 4 images, 0 backgrounds, 0 co
# val: Fast image access  (ping: 0.10.0 ms, read: 252.684.4 MB/s, size: 54.0 KB)
# val: Scanning E:\00.MOTHER_BOXES\code\modification\datasets\coco8\labels\val.cache... 4 images, 0 backgrounds, 0 corrup
# Plotting labels to runs\detect\train127\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# Adaptor LR: 0.000119
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\detect\train127
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10         0G      1.029      1.927      1.343         13        640: 100%|██████████| 1/1 [00:05<00:00,  5.57
# Epoch 1: cls_distill_loss=0.006714, dfl_distill_loss=2.999504, m2d2_distill_loss=2.944706, box_reg_distill_loss=0.081548, feat_l2_loss=1.001641, feat_att_loss=0.008149, feat_other_loss=0.159770
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17      0.595       0.85      0.849      0.632
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10         0G      1.263      2.464      1.612         13        640: 100%|██████████| 1/1 [00:04<00:00,  4.79
# Epoch 2: cls_distill_loss=0.007632, dfl_distill_loss=2.492711, m2d2_distill_loss=2.457710, box_reg_distill_loss=0.082393, feat_l2_loss=0.999118, feat_att_loss=0.013341, feat_other_loss=0.156444
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17      0.578       0.85      0.848      0.631
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10         0G     0.7771      2.095      1.202         13        640: 100%|██████████| 1/1 [00:05<00:00,  5.10
# Epoch 3: cls_distill_loss=0.006118, dfl_distill_loss=2.636209, m2d2_distill_loss=2.598912, box_reg_distill_loss=0.082296, feat_l2_loss=0.989953, feat_att_loss=0.013859, feat_other_loss=0.152748
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17      0.591       0.85      0.849       0.65
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10         0G     0.9828      1.646       1.24         13        640: 100%|██████████| 1/1 [00:04<00:00,  4.75
# Epoch 4: cls_distill_loss=0.011405, dfl_distill_loss=3.194334, m2d2_distill_loss=3.158128, box_reg_distill_loss=0.081332, feat_l2_loss=0.984059, feat_att_loss=0.008909, feat_other_loss=0.168871
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17      0.614       0.85      0.849       0.65
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10         0G     0.7461      1.818        1.1         13        640: 100%|██████████| 1/1 [00:04<00:00,  4.65
# Epoch 5: cls_distill_loss=0.009425, dfl_distill_loss=3.634561, m2d2_distill_loss=3.576458, box_reg_distill_loss=0.080600, feat_l2_loss=0.986666, feat_att_loss=0.007706, feat_other_loss=0.151915
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<0
#                    all          4         17      0.624       0.85      0.878      0.654
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10         0G      1.229      2.656      1.528         13        640: 100%|██████████| 1/1 [00:04<00:00,  4.75
# Epoch 6: cls_distill_loss=0.006255, dfl_distill_loss=3.051961, m2d2_distill_loss=3.007799, box_reg_distill_loss=0.080853, feat_l2_loss=0.991695, feat_att_loss=0.013759, feat_other_loss=0.156897
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17      0.637       0.85      0.853      0.652
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10         0G      1.195      1.952      1.387         13        640: 100%|██████████| 1/1 [00:04<00:00,  4.70
# Epoch 7: cls_distill_loss=0.009541, dfl_distill_loss=4.051668, m2d2_distill_loss=3.920342, box_reg_distill_loss=0.079585, feat_l2_loss=1.003448, feat_att_loss=0.004699, feat_other_loss=0.163475
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<0
#                    all          4         17      0.651       0.85      0.853      0.634
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10         0G     0.9354      1.782      1.302         13        640: 100%|██████████| 1/1 [00:04<00:00,  4.78
# Epoch 8: cls_distill_loss=0.007612, dfl_distill_loss=2.595722, m2d2_distill_loss=2.587619, box_reg_distill_loss=0.082430, feat_l2_loss=0.998732, feat_att_loss=0.015531, feat_other_loss=0.154166
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17      0.651       0.85      0.875      0.637
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10         0G      1.081      1.765      1.315         13        640: 100%|██████████| 1/1 [00:04<00:00,  4.76
# Epoch 9: cls_distill_loss=0.010576, dfl_distill_loss=3.967808, m2d2_distill_loss=3.778172, box_reg_distill_loss=0.079968, feat_l2_loss=0.999654, feat_att_loss=0.004909, feat_other_loss=0.157204
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<0
#                    all          4         17      0.661       0.85      0.857      0.635
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10         0G      1.058      2.263      1.352         13        640: 100%|██████████| 1/1 [00:04<00:00,  4.74
# Epoch 10: cls_distill_loss=0.007049, dfl_distill_loss=2.964641, m2d2_distill_loss=2.913092, box_reg_distill_loss=0.080718, feat_l2_loss=1.003151, feat_att_loss=0.009233, feat_other_loss=0.156778
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17      0.668       0.85      0.855      0.636
# 10 epochs completed in 0.018 hours.
# Optimizer stripped from runs\detect\train127\weights\last.pt, 5.5MB
# Optimizer stripped from runs\detect\train127\weights\best.pt, 5.5MB
#
# Validating runs\detect\train127\weights\best.pt...
# Ultralytics 8.3.184  Python-3.12.4 torch-2.5.1+cpu CPU (Intel Core(TM) i7-4700HQ 2.40GHz)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17      0.623       0.85      0.873      0.653
#                 person          3         10      0.619        0.6      0.595      0.283
#                    dog          1          1      0.558          1      0.995      0.796
#                  horse          1          2      0.701          1      0.995      0.675
#               elephant          1          2      0.391        0.5      0.662      0.274
#               umbrella          1          1      0.589          1      0.995      0.995
#           potted plant          1          1      0.877          1      0.995      0.895
# Speed: 4.3ms preprocess, 151.8ms inference, 0.0ms loss, 3.2ms postprocess per image
# Results saved to runs\detect\train127
